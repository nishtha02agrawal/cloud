# %% [markdown]
# <a href="https://colab.research.google.com/github/nishtha02agrawal/cloud/blob/main/data_cleaning/data_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hi')
